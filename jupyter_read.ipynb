# %%
import pandas as pd
import numpy as np
import random
import string
np.random.seed(56)

# %%
def id():
    return ''.join(random.choice(string.ascii_letters) for i in range(5))

# %%
def score():
    return random.randint(0,100)

# %%
df = pd.DataFrame([[random.randint(0,100) for i in range(4)] for i in range(10)],
               columns=["국어","수학","사회","영어"], 
               index=["".join(random.choice(string.ascii_letters) for i in range(5)) for i in range(10)])

# %%
df
# Out:
#        국어  수학  사회  영어
# Ldfho  83  60  22  41
# okIDl  44  34  80  27
# hgCtN  41  59  61  76
# nkSRo  48  30  38  30
# XJzmp  30   2  31  52
# iRodz  94  67  67  15
# oYVtF  61  27  68  26
# EksGf  45  20  84  47
# njPJA  95  47  40  36
# CcFSb  27  48  61  75

# %%
df.loc[:,"국어":"사회"]
# Out:
#        국어  수학  사회
# Ldfho  83  60  22
# okIDl  44  34  80
# hgCtN  41  59  61
# nkSRo  48  30  38
# XJzmp  30   2  31
# iRodz  94  67  67
# oYVtF  61  27  68
# EksGf  45  20  84
# njPJA  95  47  40
# CcFSb  27  48  61

# %%
df.iloc[[0],:]
# Out:
#        국어  수학  사회  영어
# Ldfho  83  60  22  41

# %%
#체육이 추가되었습니다. 기존 학생들에게 각 랜덤으로 추가하시오.

df.loc[:,'체육'] = pd.Series([random.randint(0,100) for i in range(10)], index=df.index)
df
# Out:
#        국어  수학  사회  영어   체육
# Ldfho  83  60  22  41   48
# okIDl  44  34  80  27   47
# hgCtN  41  59  61  76    9
# nkSRo  48  30  38  30   99
# XJzmp  30   2  31  52  100
# iRodz  94  67  67  15   37
# oYVtF  61  27  68  26    6
# EksGf  45  20  84  47    4
# njPJA  95  47  40  36   49
# CcFSb  27  48  61  75   24

# %%
#각 학생들의 점수의 총합을 표현하는 컬럼을 추가하세요.

df['총점'] = df.sum(axis=1)
df
# Out:
#        국어  수학  사회  영어   체육   총점
# Ldfho  83  60  22  41   48  254
# okIDl  44  34  80  27   47  232
# hgCtN  41  59  61  76    9  246
# nkSRo  48  30  38  30   99  245
# XJzmp  30   2  31  52  100  215
# iRodz  94  67  67  15   37  280
# oYVtF  61  27  68  26    6  188
# EksGf  45  20  84  47    4  200
# njPJA  95  47  40  36   49  267
# CcFSb  27  48  61  75   24  235

# %%
#모든 학생의 과목당 총점을 표현하는 row을 추가하세요.

list = df.sum().tolist()
list
# Out:
# [568, 394, 552, 425, 423, 2362]

# %%
df.loc["과목 총점"] = list

# %%
df
# Out:
#         국어   수학   사회   영어   체육    총점
# Ldfho   83   60   22   41   48   254
# okIDl   44   34   80   27   47   232
# hgCtN   41   59   61   76    9   246
# nkSRo   48   30   38   30   99   245
# XJzmp   30    2   31   52  100   215
# iRodz   94   67   67   15   37   280
# oYVtF   61   27   68   26    6   188
# EksGf   45   20   84   47    4   200
# njPJA   95   47   40   36   49   267
# CcFSb   27   48   61   75   24   235
# 과목 총점  568  394  552  425  423  2362

# %%
df.drop("과목 총점")
# Out:
#        국어  수학  사회  영어   체육   총점
# Ldfho  83  60  22  41   48  254
# okIDl  44  34  80  27   47  232
# hgCtN  41  59  61  76    9  246
# nkSRo  48  30  38  30   99  245
# XJzmp  30   2  31  52  100  215
# iRodz  94  67  67  15   37  280
# oYVtF  61  27  68  26    6  188
# EksGf  45  20  84  47    4  200
# njPJA  95  47  40  36   49  267
# CcFSb  27  48  61  75   24  235
