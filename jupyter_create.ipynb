# %%
import pandas as pd
import numpy as np
import random
import string
np.random.seed(56)

# %%
pd.DataFrame([[4,7,10],[5,8,11],[6,9,12]],index=[1,2,3],columns=['a','b','c'])
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
pd.DataFrame([[1,2],[3,4]], columns=['A','B'],index=[1,2] )
# Out:
#    A  B
# 1  1  2
# 2  3  4

# %%
pd.Series({"한국":"서울","일본":"도쿄","중국":"베이징"})
# Out:
# 한국     서울
# 일본     도쿄
# 중국    베이징
# dtype: object

# %%
''.join(random.choice(string.ascii_letters) for i in range(5))
# Out:
# 'tQtVQ'

# %%
pd.DataFrame([[random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100)],
             [random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100)],
             [random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100)],
             [random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100)],
             [random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100)],
             [random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100)],
             [random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100)],
             [random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100)],
             [random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100)],
             [random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100),
               random.randint(0,100)]],
            columns=["국어","수학","사회","영어"], 
            index=[["".join(random.choice(string.ascii_letters) for i in range(5)),
                    "".join(random.choice(string.ascii_letters) for i in range(5)),
                    "".join(random.choice(string.ascii_letters) for i in range(5)),
                    "".join(random.choice(string.ascii_letters) for i in range(5)),
                    "".join(random.choice(string.ascii_letters) for i in range(5)),
                    "".join(random.choice(string.ascii_letters) for i in range(5)),
                    "".join(random.choice(string.ascii_letters) for i in range(5)),
                    "".join(random.choice(string.ascii_letters) for i in range(5)),
                    "".join(random.choice(string.ascii_letters) for i in range(5)),
                    "".join(random.choice(string.ascii_letters) for i in range(5)),]])
# Out:
#        국어  수학  사회  영어
# CTHie  21  92  57  56
# tTaBN  27  20  52  42
# nGbmQ  77  40  22  91
# hFRzr  90  47  64  35
# xqxSD  81  98  79  41
# yuTte  84  95  28  53
# VGozd  90  92  50  53
# omBcf   2  58  92  26
# Frqmg  94  73  87  51
# HYXyP  93   4  17  35

# %%
pd.DataFrame(np.random.randint(0, 100, size=(10, 4)),
             index=list((''.join(random.choice(string.ascii_letters) for i in range(5))) for i in range(10)),
             columns=['국어', '영어', '수학', '사회']
            )
# Out:
#        국어  영어  수학  사회
# Lsqit  50  95   1  59
# WNBeP  37  80  27  86
# XnGEs   8   2  13  23
# VrIhA  22  48  83  52
# bXuqW  39  50  20   5
# ixqUo  48  55  90  49
# QBFad  97  56  54  36
# fUjJU  93  33  87  88
# LuuJa  29  52  27  86
# LKjQA  34  90  85  96

# %%
df = pd.DataFrame({"국어":score(), "영어":score(), "수학":score(), "사회":score()}, index=[id()])
for i in range(1,10):
    df.loc[id()] = {"국어":score(), "영어":score(), "수학":score(), "사회":score()}
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-5f51b03da301> in <module>
# ----> 1 df = pd.DataFrame({"국어":score(), "영어":score(), "수학":score(), "사회":score()}, index=[id()])
#       2 for i in range(1,10):
#       3     df.loc[id()] = {"국어":score(), "영어":score(), "수학":score(), "사회":score()}
#       4 df
#
# NameError: name 'score' is not defined
